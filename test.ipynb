# %%
using Plots, Interact
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1317
# ┌ Info: Precompiling Interact [c601a237-2ae4-5e1e-952c-7a85b0c7eef1]
# └ @ Base loading.jl:1317
# ...

# %%
xs = range(1,stop=2,length=201)
ys = [cos(x) for x in xs]
Plots.plot(xs,ys)
# Out:
# (process:17920): GLib-GIO-WARNING **: 14:03:10.052: Unexpectedly, UWP app `KDEe.V.Okular_20.1202.546.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs
